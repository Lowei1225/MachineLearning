# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 4.7 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://marina-distance-drapery.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://marina-distance-drapery.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent（人工智慧代理人），簡而言之，是一個**能夠感知其環境、獨立地做出決策、並採取行動以達成特定目標的人工智慧實體。**
#
# 它是一種將人工智慧技術應用於實際行動和互動的框架。
#
# ### AI Agent 的核心概念與特徵：
#
# 1.  **感知 (Perception)：** AI Agent 必須能夠「看到」或「聽到」其所處的環境。這通常透過各種感測器或數據輸入來實現，例如：
#     *   文字（如聊天機器人接收的用戶輸入）
#     *   圖像/影片（如自動駕駛汽車的攝像頭）
#     *   聲音（如語音助理接收的指令）
#     *   感測器數據（如機器人接收的溫度、距離等）
#     *   資料庫或網路資訊
#
# 2.  **決策/思考 (Decision-making / Thinking)：** 在感知到環境後，AI Agent 會利用其內建的知識、規則、演算法或機器學習模型來處理資訊，並決定下一步的最佳行動。這包括：
#     *   理解輸入的意圖
#     *   分析情況
#     *   預測結果
#     *   規劃行動步驟
#
# 3.  **行動 (Action)：** 根據其決策，AI Agent 會在環境中執行某些操作。這些操作可以是：
#     *   輸出文字回應（如聊天機器人）
#     *   移動物理部件（如機器人手臂）
#     *   控制車輛方向和速度（如自動駕駛）
#     *   發送指令給其他系統（如自動化交易系統）
#     *   顯示資訊或播放聲音
#
# 4.  **環境 (Environment)：** AI Agent 所操作的上下文。環境可以是物理世界（如機器人、自動駕駛汽車）、數位世界（如軟體代理人、聊天機器人、遊戲AI）或抽象世界（如數據分析代理人）。
#
# 5.  **目標導向 (Goal-Oriented)：** 每個 AI Agent 都被設計來達成一個或多個特定目標。它會不斷地調整其感知、決策和行動，以更有效地逼近這些目標。
#
# 6.  **自主性 (Autonomy)：** 一旦設定好，AI Agent 可以在沒有持續人工干預的情況下獨立運作，執行任務並響應環境變化。自主性的程度因 Agent 的複雜度而異。
#
# 7.  **學習 (Learning - often)：** 許多進階的 AI Agent 能夠從經驗中學習，改進其性能、知識和決策能力，使其在未來能更好地達成目標。
#
# ### AI Agent 的運作循環：
#
# 一個典型的 AI Agent 會遵循一個不斷重複的「感知-思考-行動」循環：
# **感知環境 → 處理資訊與決策 → 執行行動 → 感知新的環境狀態 → ...**
#
# ### 常見的 AI Agent 範例：
#
# *   **聊天機器人/虛擬助理 (Chatbots / Virtual Assistants)：** 如 Siri、Alexa、Google Assistant 或 ChatGPT。它們感知用戶的語音或文字輸入，理解意圖，做出回應，並執行指令（如播放音樂、設定提醒）。
# *   **自動駕駛汽車 (Self-driving Cars)：** 感知道路、交通、行人等環境資訊，決策加速、煞車、轉向，並實際執行這些操作。
# *   **推薦系統 (Recommendation Systems)：** 感知用戶的瀏覽歷史、購買記錄，決策推薦哪些商品或內容，並將其呈現給用戶。
# *   **工業機器人 (Industrial Robots)：** 感知生產線上的物件，決策如何抓取、移動或組裝，並執行精確的物理操作。
# *   **遊戲 AI (Game AI)：** 感知遊戲世界的狀態、玩家的動作，決策下一步的策略或行動，並在遊戲中執行這些動作。
# *   **股票交易機器人 (Stock Trading Bots)：** 感知市場數據、新聞，決策買入或賣出股票，並執行交易指令。
#
# 總之，AI Agent 代表了一種將人工智慧從單純的數據分析或模式識別，提升到能夠自主地與環境互動並達成特定目的的更高層次應用。隨著AI技術的發展，AI Agent 將在越來越多的領域發揮關鍵作用。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學 (Ming Hsin University of Science and Technology, 簡稱明新科大) 是一所位於台灣新竹縣的歷史悠久且聲譽卓著的私立科技大學。
#
# 以下是明新科技大學的簡要介紹：
#
# 1.  **創校歷史與發展：**
#     *   創立於**1966年**，前身為「明新工業專科學校」。
#     *   經過多年的發展與升格，於**2002年**正式改制為科技大學。其發展脈絡反映了台灣技職教育從專科到學院再到科技大學的演變。
#
# 2.  **地理位置優勢：**
#     *   坐落於**新竹縣新豐鄉**，鄰近台灣高科技產業重鎮——**新竹科學園區**。
#     *   這一優越的地理位置使得明新科大在**產學合作**方面具有得天獨厚的優勢，與眾多高科技企業建立了緊密的合作關係，為學生提供豐富的實習和就業機會。
#
# 3.  **教育理念與特色：**
#     *   學校秉持「**誠、樸、精、勤**」的校訓。
#     *   核心教育理念為「**實務致用、產業鏈結**」，強調將學術知識與實際應用緊密結合，培養學生具備職場競爭力。
#     *   課程設計緊密結合產業需求，注重學生**動手實作能力**的培養。
#
# 4.  **學術組織與科系：**
#     *   設有工學、管理、服務事業、設計學院等，提供多元化的學術與技職教育。
#     *   科系涵蓋電機、電子、機械、資工、土木、旅館管理、餐飲管理、幼兒保育、多媒體設計、時尚造型設計、觀光事業等領域，滿足不同學生的專業志向和產業人才需求。
#
# 5.  **畢業生表現與社會評價：**
#     *   明新科大的畢業生在就業市場上具有良好的競爭力，**就業率高**，廣受業界好評。
#     *   學校積極推動國際交流，鼓勵學生拓展國際視野，培養具備全球移動力的專業人才。
#
# 總體而言，明新科技大學是一所深耕技職教育、與產業脈動緊密結合、並致力於培養國家與社會所需專業人才的優質學府。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):   #AI 來去使用AI
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"Ua6692ca970e3a5c8679351bf1eb1a473","events":[{"type":"message","message":{"type":"text","id":"615031281759551866","quoteToken":"HW3vYZgo-hc8lUqLvavC_MBo68HJc25EeJD966uL0mhLkTfcaEsclJabEEPzJT_JQdGsWz7SV51AkiPr3hHcVeCJFsKFgwXqLCWI3GNZaM4AnCa2ySyybvLyx4OpomBMp7gB7ovbbq7FK5NKJGffJQ","markAsReadToken":"MnW4VuS5BFzluFwaz9XnwZzcLha26386HIiccFVUvjNCCkMgKsjzEoShqpfBd8h3qlBOM4gMIdb_1q1Zvh716jG9Dgfd3B6CViko3Gr4lpQN2sPYtOIMN1Te7VAc0ktTfKWsqz1J6B_8SpHTikslIRgmpUYovQ4rCPIu5OhIO1-_xgNsecCov9apS1EZjxz8_kK3umjMG23SCOkP-TtlwQ","text":"AI 簡介明新科大"},"webhookEventId":"01KS6SQHME55CGWRQYFPA67YBQ","deliveryContext":{"isRedelivery":false},"timestamp":1779418514944,"source":{"type":"user","userId":"Ueea9bd8ab131bc5c9ade769c026be174"},"replyToken":"f6edc363954441abba283fe24a430987","mode":"active"}]}
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/flask/app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_4891/599411346.py", line 39, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.12/dist-packages/linebot/v3/webhook.py", line 242, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.12/dist-packages/linebot/v3/webhook.py", line 254, in __invoke_func
#     func(event)
#   File "/tmp/ipykernel_4891/599411346.py", line 54, in handle_message
#     reply_text = stateless_query(prompt)
#                  ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_4891/3370445098.py", line 2, in stateless_query
#     response = client.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/models.py", line 5864, in generate_content
#     response = self._generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/models.py", line 4526, in _generate_content
#     response = self._api_client.request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py", line 1402, in request
#     response = self._request(http_request, http_options, stream=False)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py", line 1238, in _request
#     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/__init__.py", line 470, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/__init__.py", line 371, in iter
#     result = action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/__init__.py", line 413, in exc_check
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/__init__.py", line 184, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/local/lib/python3.12/dist-packages/tenacity/__init__.py", line 473, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py", line 1215, in _request_once
#     errors.APIError.raise_for_response(response)
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/errors.py", line 134, in raise_for_response
#     cls.raise_error(response.status_code, response_json, response)
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/errors.py", line 161, in raise_error
#     raise ServerError(status_code, response_json, response)
# google.genai.errors.ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:55:25] "POST / HTTP/1.1" 500 -
# BODY:  {"destination":"Ua6692ca970e3a5c8679351bf1eb1a473","events":[{"type":"message","message":{"type":"text","id":"615031506103960126","quoteToken":"YkUu8utmg7oAnZh-TpS2gsrPMb5msa_qbDsn4LFAj_5WzF2NWsMenPoy-T1v3wQybDIMlofAKfMxIRtKDaG_xbGUSCWGZp4ZRXiO0bgVj5moTOqwM7P4kC9daXSPinioHfo-EZ5eNdWIen7j7H35Eg","markAsReadToken":"IRA4PTqBtjRlzw12VavEWYeQ5oqsOLn6VDebrvNGikIeZ-sAKmdYK7GOvZcqkFI0OnbYSrEgOq_d9_kWvZI0aaxf60w00izTjEZeTCbvB7YYGR8PoJ9nUP1JyJ5QTLPRDm4YCQv_2ttkgAjaqlREn9_XKIyHV9xVzXJgH6b1IiBsTCNOqc9ik8aq57fBpZ5ahKwvJVlYhhmzmx2aNhI2-g","text":"AI 介紹明新科大"},"webhookEventId":"01KS6SVM8H7FP4FRVGZMPY7C4G","deliveryContext":{"isRedelivery":false},"timestamp":1779418648487,"source":{"type":"user","userId":"Ueea9bd8ab131bc5c9ade769c026be174"},"replyToken":"26af98d86c7e4be98d34c26be5c8dbe5","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:57:43] "POST / HTTP/1.1" 200 -
# WARNING:pyngrok.process.ngrok:t=2026-05-22T02:59:55+0000 lvl=warn msg="Stopping forwarder" name=linebot_tunnel acceptErr="failed to accept connection: Listener closed"
